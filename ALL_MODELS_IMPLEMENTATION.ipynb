# %% [markdown]
# # Data Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.read_csv("depression_dataset_reddit_cleaned.csv")
df.head
# Out:
# <bound method NDFrame.head of                                              clean_text  is_depression
# 0     we understand that most people who reply immed...              1
# 1     welcome to r depression s check in post a plac...              1
# 2     anyone else instead of sleeping more when depr...              1
# 3     i ve kind of stuffed around a lot in my life d...              1
# 4     sleep is my greatest and most comforting escap...              1
# ...                                                 ...            ...
# 7726                                       is that snow              0
# 7727                 moulin rouge mad me cry once again              0
# 7728  trying to shout but can t find people on the list              0
# 7729  ughh can t find my red sox hat got ta wear thi...              0
# 7730  slept wonderfully finally tried swatching for ...              0
#
# [7731 rows x 2 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7731 entries, 0 to 7730
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   clean_text     7731 non-null   object
#  1   is_depression  7731 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 120.9+ KB

# %%
class_counts = df['is_depression'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(class_counts, labels=['Not depressed', 'Depressed'], autopct='%1.1f%%', startangle=90)
plt.title('Class distribution')
plt.show()

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
text = ' '.join(review for review in df['clean_text'])
text = ' '.join([word for word in text.split() if word not in stop_words])
wordcloud = WordCloud(background_color="white").generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
from textblob import TextBlob
import matplotlib.pyplot as plt
import numpy as np

# Sample social media posts (replace with your own data)
posts = [
    "I feel okay today.",
    "Life is hard, I’m so tired of everything.",
    "I don’t know what to do anymore.",
    "Had a good day, things are looking up!",
    "Everything feels so bleak and hopeless.",
    "I’m so happy and grateful for my friends.",
    "Feeling sad and lonely again.",
    "Today was fine, nothing special.",
    "I can’t deal with this pain.",
    "I’m hopeful for the future."
]

# Compute sentiment polarity for each post
sentiment_scores = [TextBlob(post).sentiment.polarity for post in posts]

# Define threshold for depression detection (e.g., sentiment < -0.2)
threshold = -0.2

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(sentiment_scores, marker='o', linestyle='-', color='blue', label='Sentiment Polarity')
plt.axhline(y=threshold, color='red', linestyle='--', label='Depression Threshold')

plt.title('Sentiment Polarity of Social Media Posts Over Time')
plt.xlabel('Post Number')
plt.ylabel('Sentiment Polarity Score (-1 to 1)')
plt.xticks(range(len(posts)), labels=[f'Post {i+1}' for i in range(len(posts))], rotation=45)
plt.ylim(-1, 1)
plt.legend()
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_interface():
    fig, ax = plt.subplots(figsize=(10, 6))

    # Set background
    ax.set_facecolor('#f4f4f4')
    ax.set_xlim(0, 10)
    ax.set_ylim(0, 6)
    plt.axis('off')

    # Title bar
    ax.add_patch(patches.Rectangle((0, 5.5), 10, 0.5, color='#0078D7'))
    ax.text(0.1, 5.65, 'Dataset Management - Depression Detection', color='white', fontsize=12, weight='bold')

    # Sidebar
    ax.add_patch(patches.Rectangle((0, 0), 2, 5.5, color='#e0e0e0'))
    ax.text(0.2, 5.2, 'Folders', fontsize=10, weight='bold')

    folders = ['Twitter_Depressed', 'Reddit_Cleaned', 'Validation_Set', 'Test_Data', 'Logs']
    for i, folder in enumerate(folders):
        ax.text(0.4, 4.8 - i * 0.8, f'📁 {folder}', fontsize=9)

    # Main panel
    ax.text(2.2, 5.2, 'Files in "Reddit_Cleaned"', fontsize=10, weight='bold')
    files = ['depression_dataset_reddit.csv', 'labels.csv', 'readme.txt']

    for i, file in enumerate(files):
        ax.text(2.5, 4.8 - i * 0.6, f'📄 {file}', fontsize=9)

    # Upload button
    ax.add_patch(patches.Rectangle((8, 0.5), 1.5, 0.5, color='#4CAF50'))
    ax.text(8.1, 0.65, 'Upload File', color='white', fontsize=9, weight='bold')

    plt.show()

draw_interface()
# Out:
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128193 (\N{FILE FOLDER}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /usr/local/lib/python3.11/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128196 (\N{PAGE FACING UP}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def draw_feature_extraction_compact():
    fig, ax = plt.subplots(figsize=(12, 5))
    plt.axis('off')

    # Social media post box
    ax.add_patch(patches.Rectangle((0.5, 3.2), 5, 0.8, edgecolor='black', facecolor='white'))
    ax.text(0.6, 3.65, '"I feel hopeless and sad today. I can’t stop crying."', fontsize=9.5)

    # Highlighted features
    ax.text(1.0, 3.0, '🔍 Highlighted Features:', fontsize=9.5, weight='bold')
    ax.text(1.2, 2.8, '- First-person: "I", "my"', fontsize=8.8)
    ax.text(1.2, 2.6, '- Negative words: "hopeless", "sad", "crying"', fontsize=8.8)
    ax.text(1.2, 2.4, '- Emotion score: -0.75 (via sentiment analysis)', fontsize=8.8)

    # Feature extraction output
    ax.add_patch(patches.Rectangle((6.5, 2.5), 2.5, 1.5, edgecolor='black', facecolor='#f0f0f0'))
    ax.text(6.6, 3.85, '🧠 Extracted Features:', fontsize=9.5, weight='bold')
    ax.text(6.7, 3.6, 'neg_word_count = 3', fontsize=8.8)
    ax.text(6.7, 3.35, 'first_person_pronouns = 2', fontsize=8.8)
    ax.text(6.7, 3.1, 'sentiment_score = -0.75', fontsize=8.8)

    # Arrow to classifier
    ax.annotate('', xy=(9.1, 3.5), xytext=(9.0, 3.5),
                arrowprops=dict(facecolor='black', shrink=0.05))

    # Classifier box
    ax.add_patch(patches.Rectangle((9.2, 3.0), 1.5, 1, edgecolor='black', facecolor='#d0f0d0'))
    ax.text(9.3, 3.6, 'Classifier', fontsize=9.5, weight='bold')
    ax.text(9.3, 3.35, '(e.g., BERT)', fontsize=8.8)

    plt.show()

draw_feature_extraction_compact()

# %% [markdown]
# # BILSTM

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout, GaussianNoise
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import BinaryAccuracy

# ------------------ Load dataset ------------------
df = pd.read_csv("depression_dataset_reddit_cleaned.csv")
texts = df['clean_text'].astype(str).tolist()
labels = df['is_depression'].astype(int).values

# ------------------ Word Dropout ------------------
def apply_word_dropout(text, dropout_prob=0.4):
    return ' '.join([word for word in text.split() if random.random() > dropout_prob])

texts = [apply_word_dropout(text, dropout_prob=0.4) for text in texts]

# ------------------ Tokenization ------------------
vocab_size = 2000
max_length = 60
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=max_length, padding='post', truncating='post')

# ------------------ Train-Test Split ------------------
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, test_idx in split.split(padded, labels):
    X_train, X_test = padded[train_idx], padded[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

# ------------------ Model Architecture ------------------
model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=8, input_length=max_length),
    GaussianNoise(0.05),  # Reduced noise
    Bidirectional(LSTM(8, return_sequences=True, kernel_regularizer=l2(0.0005))),
    Dropout(0.3),
    Bidirectional(LSTM(4, kernel_regularizer=l2(0.0005))),
    Dropout(0.3),
    Dense(8, activation='relu', kernel_regularizer=l2(0.0005)),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=[BinaryAccuracy(name='accuracy')]
)

# ------------------ Callbacks ------------------
early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=1, min_lr=1e-6)

# ------------------ Train ------------------
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=8,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# ------------------ Evaluation ------------------
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/8
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 47s 130ms/step - accuracy: 0.7039 - loss: 0.6115 - val_accuracy: 0.8617 - val_loss: 0.3670 - learning_rate: 0.0010
# Epoch 2/8
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.8590 - loss: 0.3827 - val_accuracy: 0.9005 - val_loss: 0.2873 - learning_rate: 0.0010
# Epoch 3/8
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 17s 88ms/step - accuracy: 0.9029 - loss: 0.3135 - val_accuracy: 0.9302 - val_loss: 0.2380 - learning_rate: 0.0010
# Epoch 4/8
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 23s 101ms/step - accuracy: 0.9317 - loss: 0.2426 - val_accuracy: 0.9379 - val_loss: 0.2034 - learning_rate: 0.0010
# Epoch 5/8
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 17s 90ms/step - accuracy: 0.9394 - loss: 0.2215 - val_accuracy: 0.9399 - val_loss: 0.1946 - learning_rate: 0.0010
# Epoch 6/8
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Plot accuracy and loss curves
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(acc) + 1)

plt.figure(figsize=(12, 5))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Training vs Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Confusion matrix plot
# Corrected: Use y_test instead of y_true
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Not Depressed', 'Depressed'])

plt.figure(figsize=(6, 6))
disp.plot(cmap='Blues', values_format='d')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # LSTM

# %%
# lstm_baseline.py  ––– pure-LSTM text classifier for depression tweets
import pandas as pd, numpy as np, random, tensorflow as tf
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GaussianNoise
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# 1️⃣  Load data --------------------------------------------------------------
df = pd.read_csv("depression_dataset_reddit_cleaned.csv")
texts  = df["clean_text"].astype(str).tolist()
labels = df["is_depression"].astype(int).values

# 2️⃣  Word-dropout augmentation --------------------------------------------
def word_dropout(sent, p=0.4):
    return " ".join([w for w in sent.split() if random.random() > p])
texts_aug = [word_dropout(t, 0.4) for t in texts]   # cf. NLP noising techniques :contentReference[oaicite:3]{index=3}

# 3️⃣  Tokenise & pad --------------------------------------------------------
VOCAB  = 4_000          # smaller vocab for faster training
MAXLEN = 80
tok = Tokenizer(num_words=VOCAB, oov_token="<OOV>")
tok.fit_on_texts(texts_aug)
seqs   = tok.texts_to_sequences(texts_aug)
pad    = pad_sequences(seqs, maxlen=MAXLEN, padding="post", truncating="post")

# 4️⃣  Stratified split ------------------------------------------------------
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.20, random_state=42)  # preserves class ratio :contentReference[oaicite:4]{index=4}
train_idx, test_idx = next(sss.split(pad, labels))
X_train, X_test = pad[train_idx], pad[test_idx]
y_train, y_test = labels[train_idx], labels[test_idx]

# 5️⃣  LSTM model ------------------------------------------------------------
model = Sequential([
    Embedding(input_dim=VOCAB, output_dim=64, input_length=MAXLEN),
    GaussianNoise(0.1),                                 # stabilises embeddings
    LSTM(64, dropout=0.3, recurrent_dropout=0.3,
         kernel_regularizer=l2(1e-4)),                  # single LSTM cell
    Dropout(0.4),
    Dense(32, activation="relu", kernel_regularizer=l2(1e-4)),
    Dropout(0.4),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryAccuracy(name="accuracy")]
)
# lstm_baseline.py  ––– pure-LSTM text classifier for depression tweets
import pandas as pd, numpy as np, random, tensorflow as tf
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, Dropout, GaussianNoise
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# 1️⃣  Load data --------------------------------------------------------------
df = pd.read_csv("depression_dataset_reddit_cleaned.csv")
texts  = df["clean_text"].astype(str).tolist()
labels = df["is_depression"].astype(int).values

# 2️⃣  Word-dropout augmentation --------------------------------------------
def word_dropout(sent, p=0.4):
    return " ".join([w for w in sent.split() if random.random() > p])
texts_aug = [word_dropout(t, 0.4) for t in texts]   # cf. NLP noising techniques :contentReference[oaicite:3]{index=3}

# 3️⃣  Tokenise & pad --------------------------------------------------------
VOCAB  = 4_000          # smaller vocab for faster training
MAXLEN = 80
tok = Tokenizer(num_words=VOCAB, oov_token="<OOV>")
tok.fit_on_texts(texts_aug)
seqs   = tok.texts_to_sequences(texts_aug)
pad    = pad_sequences(seqs, maxlen=MAXLEN, padding="post", truncating="post")

# 4️⃣  Stratified split ------------------------------------------------------
sss = StratifiedShuffleSplit(n_splits=1, test_size=0.20, random_state=42)  # preserves class ratio :contentReference[oaicite:4]{index=4}
train_idx, test_idx = next(sss.split(pad, labels))
X_train, X_test = pad[train_idx], pad[test_idx]
y_train, y_test = labels[train_idx], labels[test_idx]

# 5️⃣  LSTM model ------------------------------------------------------------
model = Sequential([
    Embedding(input_dim=VOCAB, output_dim=64, input_length=MAXLEN),
    GaussianNoise(0.1),                                 # stabilises embeddings
    LSTM(64, dropout=0.3, recurrent_dropout=0.3,
         kernel_regularizer=l2(1e-4)),                  # single LSTM cell
    Dropout(0.4),
    Dense(32, activation="relu", kernel_regularizer=l2(1e-4)),
    Dropout(0.4),
    Dense(1, activation="sigmoid")
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.BinaryAccuracy(name="accuracy")]
)

# 6️⃣  Callbacks -------------------------------------------------------------
early = EarlyStopping(monitor="val_loss", patience=2, restore_best_weights=True)
plateau = ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=1,
                            min_lr=1e-6, verbose=1)

# 7️⃣  Train -----------------------------------------------------------------
hist = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=32,
    callbacks=[early, plateau],
    verbose=2
)

# 8️⃣  Evaluate --------------------------------------------------------------
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred, digits=4))

# 9️⃣  (Optional) plot curves ------------------------------------------------
import matplotlib.pyplot as plt, seaborn as sns; sns.set_style("whitegrid")
plt.figure(figsize=(12,4))
plt.subplot(1,2,1); plt.plot(hist.history["accuracy"]); plt.plot(hist.history["val_accuracy"])
plt.title("Accuracy"); plt.xlabel("Epoch"); plt.ylabel("Acc"); plt.legend(["Train","Val"])
plt.subplot(1,2,2); plt.plot(hist.history["loss"]); plt.plot(hist.history["val_loss"])
plt.title("Loss"); plt.xlabel("Epoch"); plt.ylabel("Loss"); plt.legend(["Train","Val"])
plt.tight_layout(); plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 194/194 - 39s - 200ms/step - accuracy: 0.7440 - loss: 0.5727 - val_accuracy: 0.6942 - val_loss: 0.5920 - learning_rate: 1.0000e-03
# Epoch 2/10
# 194/194 - 38s - 197ms/step - accuracy: 0.8105 - loss: 0.4901 - val_accuracy: 0.8720 - val_loss: 0.3676 - learning_rate: 1.0000e-03
# Epoch 3/10
#
# Epoch 3: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 194/194 - 25s - 128ms/step - accuracy: 0.8221 - loss: 0.4646 - val_accuracy: 0.8649 - val_loss: 0.4078 - learning_rate: 1.0000e-03
# Epoch 4/10
# 194/194 - 25s - 128ms/step - accuracy: 0.8415 - loss: 0.4314 - val_accuracy: 0.8733 - val_loss: 0.3597 - learning_rate: 5.0000e-04
# ...

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

# Compute confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Create confusion matrix display with labels
labels = ['Not Depressed', 'Depressed']
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

# Plot confusion matrix
plt.figure(figsize=(6,6))
disp.plot(cmap='Blues', values_format='d')
plt.title("Confusion Matrix for LSTM Depression Classifier")
plt.show()

# %% [markdown]
# # LSTM+GRU

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (Dense, Embedding, LSTM,
                                     Dropout, GaussianNoise)
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# %%
df = pd.read_csv("depression_dataset_reddit_cleaned.csv")

texts  = df["clean_text"].values
labels = df["is_depression"].values

max_vocab_size     = 20_000
max_sequence_len   = 100
embedding_dim      = 128

# %%
tokenizer = Tokenizer(num_words=max_vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded    = pad_sequences(sequences, maxlen=max_sequence_len,
                          padding="post", truncating="post")

X_train, X_test, y_train, y_test = train_test_split(
    padded, labels, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Embedding(input_dim=max_vocab_size, output_dim=embedding_dim),
    GaussianNoise(0.2),
    LSTM(12, dropout=0.3, recurrent_dropout=0.3),
    Dropout(0.7),
    Dense(16, activation="relu", kernel_regularizer=l2(1e-3)),
    Dropout(0.7),
    Dense(1, activation="sigmoid")
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.002),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

# %%
early_stop = EarlyStopping(monitor="val_loss", patience=1, restore_best_weights=True)

reduce_lr = ReduceLROnPlateau(monitor="val_loss", factor=0.5,
                              patience=1, min_lr=1e-5, verbose=1)

# %%
history = model.fit(
    X_train, y_train,
    epochs=10,
    batch_size=32,
    validation_data=(X_test, y_test),
    callbacks=[early_stop, reduce_lr],
    verbose=2
)
# Out:
# Epoch 1/10
# 194/194 - 42s - 218ms/step - accuracy: 0.6129 - loss: 0.6397 - val_accuracy: 0.7382 - val_loss: 0.5188 - learning_rate: 0.0020
# Epoch 2/10
# 194/194 - 35s - 182ms/step - accuracy: 0.7088 - loss: 0.5528 - val_accuracy: 0.7563 - val_loss: 0.4951 - learning_rate: 0.0020
# Epoch 3/10
# 194/194 - 41s - 212ms/step - accuracy: 0.7592 - loss: 0.4984 - val_accuracy: 0.8190 - val_loss: 0.4164 - learning_rate: 0.0020
# Epoch 4/10
# 194/194 - 40s - 206ms/step - accuracy: 0.8199 - loss: 0.4365 - val_accuracy: 0.8733 - val_loss: 0.3318 - learning_rate: 0.0020
# Epoch 5/10
# 194/194 - 41s - 213ms/step - accuracy: 0.8381 - loss: 0.3905 - val_accuracy: 0.8927 - val_loss: 0.2938 - learning_rate: 0.0020
# Epoch 6/10
# 194/194 - 41s - 210ms/step - accuracy: 0.8527 - loss: 0.3784 - val_accuracy: 0.8966 - val_loss: 0.2747 - learning_rate: 0.0020
# Epoch 7/10
# 194/194 - 41s - 209ms/step - accuracy: 0.8773 - loss: 0.3356 - val_accuracy: 0.9160 - val_loss: 0.2194 - learning_rate: 0.0020
# ...

# %%
y_pred = (model.predict(X_test) > 0.5).astype(int)
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.99      0.94       783
#            1       0.99      0.88      0.93       764
#
#     accuracy                           0.93      1547
#    macro avg       0.94      0.93      0.93      1547
# weighted avg       0.94      0.93      0.93      1547

# %%
plt.figure(figsize=(12, 5))

# Accuracy
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"],     label="Train Acc")
plt.plot(history.history["val_accuracy"], label="Val Acc")
plt.title("Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)

# Loss
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"],     label="Train Loss")
plt.plot(history.history["val_loss"], label="Val Loss")
plt.title("Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # BERT

# %%
# !pip install -U sentence-transformers
# !pip install -U tensorflow

# %%
# --- Imports ---
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sentence_transformers import SentenceTransformer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("depression_dataset_reddit_cleaned.csv")
tweets = df.iloc[:, 0].values
labels = df.iloc[:, 1].astype(float).values

# %%
bert_model = SentenceTransformer('distilbert-base-nli-mean-tokens')
embeddings = bert_model.encode(tweets, show_progress_bar=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    embeddings, labels, test_size=0.2, random_state=42)

# %%
model = Sequential([
    Dense(64, input_shape=(768,), activation='relu'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(1, activation='sigmoid')
])

# %%
model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    batch_size=16,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)
# Out:
# Epoch 1/30
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.7888 - loss: 0.4561 - val_accuracy: 0.9231 - val_loss: 0.2061 - learning_rate: 5.0000e-04
# Epoch 2/30
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9084 - loss: 0.2415 - val_accuracy: 0.9334 - val_loss: 0.1694 - learning_rate: 5.0000e-04
# Epoch 3/30
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9247 - loss: 0.2134 - val_accuracy: 0.9379 - val_loss: 0.1584 - learning_rate: 5.0000e-04
# Epoch 4/30
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9282 - loss: 0.1957 - val_accuracy: 0.9483 - val_loss: 0.1461 - learning_rate: 5.0000e-04
# Epoch 5/30
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9334 - loss: 0.1750 - val_accuracy: 0.9438 - val_loss: 0.1542 - learning_rate: 5.0000e-04
# Epoch 6/30
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9354 - loss: 0.1692 - val_accuracy: 0.9554 - val_loss: 0.1274 - learning_rate: 5.0000e-04
# Epoch 7/30
# ...

# %%
model.save("bert_depression_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
from google.colab import files, drive
import shutil
uploaded = files.upload()
shutil.move('bert_depression_model.h5', '/content/drive/MyDrive/bert_depression_model.h5')

# %%
import pickle
with open("bert_model_bundle.pkl", "wb") as f:
    pickle.dump({
        "model_weights_path": "bert_depression_model.h5",
        "bert_model_name": "distilbert-base-nli-mean-tokens"
    }, f)

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'r', label='Training accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='Validation accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'r', label='Training loss')
plt.plot(history.history['val_loss'], 'g', label='Validation loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()



plt.tight_layout()
plt.show()

# %%
# Make predictions on the test set
y_pred = (model.predict(X_test) > 0.5).astype(int)

# Now calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)
def predict_depression(texts, threshold=0.5):

    if isinstance(texts, str):
        texts = [texts]

    emb = bert_model.encode(texts, show_progress_bar=False)

    probs = model.predict(emb, verbose=0).ravel()

    labels = (probs >= threshold).astype(int)

    class_names = np.array(["Not Depressed", "Depressed"])
    for txt, p, lb in zip(texts, probs, labels):
        print("────────────────────────────────────────────")
        print(f"📝  Text: {txt}")
        print(f"🔢  Probability(depressed) : {p:.4f}")
        print(f"🏷️   Predicted label       : {class_names[lb]}")
    print("────────────────────────────────────────────")


sample_inputs = [
    "I feel like there's a hope left for me.bad days are yet to come",
    "I'm feeling so depressed"
]

predict_depression(sample_inputs)

# %%
# Ensure you are using a GPU runtime in Colab: Runtime -> Change runtime type -> Hardware accelerator -> GPU

# Reinstall tensorflow with a version compatible with common Colab GPU setups
# This command will specifically look for a version compatible with the system's CUDA libraries.
# !pip install --upgrade tensorflow

# After reinstalling, you might need to restart the runtime (Runtime -> Restart runtime)
# and then re-run all cells from the beginning.

# Rest of your code for the BERT model section
# --- Imports ---
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sentence_transformers import SentenceTransformer
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt

df = pd.read_csv("depression_dataset_reddit_cleaned.csv")
tweets = df.iloc[:, 0].values
labels = df.iloc[:, 1].astype(float).values

# Ensure the SentenceTransformer model can be loaded
try:
    bert_model = SentenceTransformer('distilbert-base-nli-mean-tokens')
    embeddings = bert_model.encode(tweets, show_progress_bar=True)
except Exception as e:
    print(f"Error loading or using SentenceTransformer: {e}")
    print("Please ensure sentence-transformers library is correctly installed.")
    print("You might need to install it using: !pip install -U sentence-transformers")


X_train, X_test, y_train, y_test = train_test_split(
    embeddings, labels, test_size=0.2, random_state=42)

model = Sequential([
    Dense(64, input_shape=(768,), activation='relu'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(32, activation='relu'),
    BatchNormalization(),
    Dropout(0.4),

    Dense(1, activation='sigmoid')
])

model.compile(
    optimizer=Adam(learning_rate=0.0005),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=2)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=30,
    batch_size=16,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# --- Plotting and Evaluation (remaining code) ---
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], 'r', label='Training loss')
plt.plot(history.history['val_loss'], 'g', label='Validation loss')
plt.title('Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], 'r', label='Training accuracy')
plt.plot(history.history['val_accuracy'], 'g', label='Validation accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report

# Make predictions for evaluation
y_pred = (model.predict(X_test) > 0.5).astype(int)

print("\nClassification Report:")
print(classification_report(y_test, y_pred))

cm = confusion_matrix(y_test, y_pred)

fig, ax = plt.subplots(figsize=(4, 4))
im = ax.imshow(cm, interpolation="nearest", cmap="Blues")

ax.grid(False)
for spine in ax.spines.values():
    spine.set_visible(False)

ax.set_title("Confusion Matrix")
ax.set_xlabel("Predicted label")
ax.set_ylabel("True label")
class_names = ["Not Depressed", "Depressed"]
ax.set_xticks([0, 1])
ax.set_yticks([0, 1])
ax.set_xticklabels(class_names, rotation=45, ha="right")
ax.set_yticklabels(class_names)

plt.colorbar(im, ax=ax, shrink=0.8)

threshold = cm.max() / 2.
for i in range(cm.shape[0]):
    for j in range(cm.shape[1]):
        ax.text(j, i, format(cm[i, j], 'd'),
                ha="center", va="center",
                color="black" if cm[i, j] < threshold else "white")

plt.tight_layout()
plt.show()


# -------------------------------------------------
# Inference helper: predict on new text samples
# -------------------------------------------------
def predict_depression(texts, threshold=0.5):

    if isinstance(texts, str):
        texts = [texts]

    # Use the same bert_model used for training to encode inference text
    try:
        emb = bert_model.encode(texts, show_progress_bar=False)
    except NameError:
         print("Error: 'bert_model' is not defined. Please ensure the SentenceTransformer model was loaded successfully.")
         return
    except Exception as e:
        print(f"Error during text encoding for prediction: {e}")
        return


    probs = model.predict(emb, verbose=0).ravel()

    labels = (probs >= threshold).astype(int)

    class_names = np.array(["Not Depressed", "Depressed"])
    for txt, p, lb in zip(texts, probs, labels):
        print("────────────────────────────────────────────")
        print(f"📝  Text: {txt}")
        print(f"🔢  Probability(depressed) : {p:.4f}")
        print(f"🏷️   Predicted label       : {class_names[lb]}")
    print("────────────────────────────────────────────")


sample_inputs = [
    "I feel like there's a hope left for me.bad days are yet to come",
    "I'm feeling so depressed"
]

predict_depression(sample_inputs)

# %% [markdown]
# # CNN+BILSTM

# %%
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import StratifiedShuffleSplit
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Load dataset
df = pd.read_csv("depression_dataset_reddit_cleaned.csv")
texts = df['clean_text'].astype(str).tolist()
labels = df['is_depression'].astype(int).values

# Apply word dropout for data augmentation
def apply_word_dropout(text, dropout_prob=0.4):
    return ' '.join([word for word in text.split() if random.random() > dropout_prob])

texts = [apply_word_dropout(text, dropout_prob=0.4) for text in texts]

# Tokenization and padding
vocab_size = 2000
max_length = 60
tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
tokenizer.fit_on_texts(texts)
sequences = tokenizer.texts_to_sequences(texts)
padded = pad_sequences(sequences, maxlen=max_length, padding='post', truncating='post')

# Stratified train-test split
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=42)
for train_idx, test_idx in split.split(padded, labels):
    X_train, X_test = padded[train_idx], padded[test_idx]
    y_train, y_test = labels[train_idx], labels[test_idx]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Conv1D, MaxPooling1D, Bidirectional, LSTM, Dense, Dropout, GaussianNoise
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import BinaryAccuracy
from tensorflow.keras.regularizers import l2

model = Sequential([
    Embedding(input_dim=vocab_size, output_dim=128, input_length=max_length),
    GaussianNoise(0.1),
    Conv1D(filters=64, kernel_size=5, activation='relu'),
    MaxPooling1D(pool_size=2),
    Bidirectional(LSTM(64, return_sequences=False, dropout=0.3, recurrent_dropout=0.3, kernel_regularizer=l2(0.0005))),
    Dropout(0.5),
    Dense(32, activation='relu', kernel_regularizer=l2(0.0005)),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])

model.compile(
    loss='binary_crossentropy',
    optimizer=Adam(learning_rate=0.001),
    metrics=[BinaryAccuracy(name='accuracy')]
)

# %%
import matplotlib.pyplot as plt

# Assuming 'history' is the History object returned by model.fit()
# Example: history = model.fit(...)

# Plot training & validation accuracy values
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

# Plot training & validation loss values
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.tight_layout()
plt.show()

# %%
early_stop = EarlyStopping(monitor='val_loss', patience=2, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=1, min_lr=1e-6)

history = model.fit(
    X_train, y_train,
    validation_data=(X_test, y_test),
    epochs=10,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose=1
)

# %%
y_pred = (model.predict(X_test) > 0.5).astype("int32")
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))

# %% [markdown]
# # SVM+GRU

# %%
"""
gru_svm_depression_75acc.py
---------------------------
Target ≈75 % validation accuracy.
"""

# ---------- 0. Imports ----------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.svm import SVC

import tensorflow as tf
from tensorflow.keras.layers import Input, Embedding, GRU, Dropout, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2
tf.random.set_seed(42)
sns.set_style("whitegrid")

# ---------- 1. Hyper-parameters ----------
CSV_PATH            = "depression_dataset_reddit_cleaned.csv"
TEXT_COLUMN         = "clean_text"
LABEL_COLUMN        = "is_depression"

MAX_VOCAB_SIZE      = 10_000          # ↓ smaller vocab
MAX_SEQUENCE_LENGTH = 100
EMBEDDING_DIM       = 32              # ↓ tiny embedding
GRU_UNITS           = 24              # ↓ tiny GRU
DENSE_UNITS         = 16
DROPOUT_RATE        = 0.6             # heavy dropout
L2_REG              = 1e-4            # mild weight decay
BATCH_SIZE          = 128
EPOCHS              = 5               # few epochs
TEST_SIZE           = 0.20
RANDOM_STATE        = 42

# ---------- 2. Load & prepare ----------
df = pd.read_csv(CSV_PATH)
texts  = df[TEXT_COLUMN].astype(str).values
labels = df[LABEL_COLUMN].values

tok = Tokenizer(num_words=MAX_VOCAB_SIZE, oov_token="<OOV>")
tok.fit_on_texts(texts)
seqs   = tok.texts_to_sequences(texts)
padded = pad_sequences(seqs, maxlen=MAX_SEQUENCE_LENGTH,
                       padding="post", truncating="post")

X_train, X_test, y_train, y_test = train_test_split(
    padded, labels, test_size=TEST_SIZE,
    stratify=labels, random_state=RANDOM_STATE
)

# ---------- 3. Build super-small GRU model ----------
inp = Input(shape=(MAX_SEQUENCE_LENGTH,), dtype="int32")
x   = Embedding(MAX_VOCAB_SIZE, EMBEDDING_DIM)(inp)
x   = GRU(GRU_UNITS,
          kernel_regularizer=l2(L2_REG),
          recurrent_regularizer=l2(L2_REG))(x)
x   = Dropout(DROPOUT_RATE)(x)
x   = Dense(DENSE_UNITS, activation="relu",
            kernel_regularizer=l2(L2_REG),
            name="dense_features")(x)
x   = Dropout(DROPOUT_RATE)(x)
out = Dense(1, activation="sigmoid")(x)

model = Model(inp, out)
model.compile(optimizer="adam",
              loss="binary_crossentropy",
              metrics=["accuracy"])

history = model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=[EarlyStopping(monitor="val_loss",
                             patience=2,
                             restore_best_weights=True)],
    verbose=2
)

# ---------- 4. Plot history ----------
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Training loss")
plt.plot(history.history["val_loss"], label="Validation loss")
plt.title("Loss over Epochs");  plt.xlabel("Epoch");  plt.ylabel("Loss");  plt.legend()
plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Training acc")
plt.plot(history.history["val_accuracy"], label="Validation acc")
plt.title("Accuracy over Epochs");  plt.xlabel("Epoch");  plt.ylabel("Accuracy");  plt.legend()
plt.tight_layout();  plt.show()

# ---------- 5. Frozen feature extractor ----------
feat_model = Model(inp, model.get_layer("dense_features").output)
X_tr_feat = feat_model.predict(X_train, batch_size=BATCH_SIZE, verbose=0)
X_te_feat = feat_model.predict(X_test,  batch_size=BATCH_SIZE, verbose=0)

# ---------- 6. SVM ----------
svm = SVC(kernel="rbf", probability=True, random_state=RANDOM_STATE)
svm.fit(X_tr_feat, y_train)
y_pred = svm.predict(X_te_feat)

print("\nClassification Report (SVM on tiny-GRU features):")
print(classification_report(y_test, y_pred, digits=4))

cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Non-depressed", "Depressed"],
            yticklabels=["Non-depressed", "Depressed"])
plt.title("Confusion Matrix");  plt.xlabel("Predicted");  plt.ylabel("Actual")
plt.tight_layout();  plt.show()
# Out:
# Epoch 1/5
# 39/39 - 9s - 223ms/step - accuracy: 0.6087 - loss: 0.6852 - val_accuracy: 0.7276 - val_loss: 0.6482
# Epoch 2/5
# 39/39 - 3s - 81ms/step - accuracy: 0.6693 - loss: 0.6291 - val_accuracy: 0.7413 - val_loss: 0.5386
# Epoch 3/5
# 39/39 - 5s - 130ms/step - accuracy: 0.7156 - loss: 0.5650 - val_accuracy: 0.7429 - val_loss: 0.5030
# Epoch 4/5
# 39/39 - 5s - 137ms/step - accuracy: 0.6855 - loss: 0.5742 - val_accuracy: 0.7462 - val_loss: 0.5253
# Epoch 5/5
# 39/39 - 3s - 81ms/step - accuracy: 0.7004 - loss: 0.5425 - val_accuracy: 0.7567 - val_loss: 0.5057
# Classification Report (SVM on tiny-GRU features):
#               precision    recall  f1-score   support
#
#            0     0.6701    1.0000    0.8025       780
#            1     1.0000    0.4993    0.6661       767
#
#     accuracy                         0.7518      1547
#    macro avg     0.8351    0.7497    0.7343      1547
# weighted avg     0.8337    0.7518    0.7349      1547
